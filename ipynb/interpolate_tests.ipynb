# %%
# %matplotlib inline
import astropy
import os
import numpy as np
import matplotlib.pyplot as plt
import random
import dimage

# %%
nx=1000
ny=1000
mean_image= np.zeros((nx,ny), dtype=np.float32)

# %%
mean_image= mean_image + 0. # add background
xgauss= 505.43
ygauss= 493.33
sgauss= 20.
amp= 30000.
ximage= np.outer(np.arange(nx, dtype=np.float32), np.ones(ny, dtype=np.float32))
yimage= np.outer(np.ones(nx, dtype=np.float32), np.arange(ny, dtype=np.float32))
r2image= (ximage-xgauss)**2+(yimage-ygauss)**2
gauss_image= amp*np.exp(-0.5*r2image/sgauss**2)/(np.sqrt(2.*np.pi)*sgauss)
mean_image= mean_image + gauss_image

# %%
new_image=mean_image+0.
dimage.dshift(new_image, 0.5, 0.0)

# %%
x=np.arange(41)+479.5
y=np.arange(41)+500.

# %%
samples= dimage.dresample(mean_image, x, y)

# %%
plt.plot(samples)
plt.plot(new_image[480:520, 500]+5.)

# %%
print samples
# Out:
# [ 260.28656006  276.67904663  293.36956787  310.29037476  327.36749268
#   344.52218628  361.67050171  378.72436523  395.59213257  412.17938232
#   428.3899231   444.12615967  459.29086304  473.78744507  487.52120972
#   500.40048218  512.33764648  523.24987793  533.06005859  541.69818115
#   549.10180664  555.21685791  559.99841309  563.41070557  565.42852783
#   566.0368042   565.23065186  563.01654053  559.41064453  554.44006348
#   548.1416626   540.56152344  531.75549316  521.78649902  510.72616577
#   498.65203857  485.64764404  471.80148315  457.20568848  441.95513916
#   426.14648438]

# %%
print mean_image[480:521, 500]
# Out:
# [ 252.22332764  268.44332886  284.99307251  301.80761719  318.81622314
#   335.94241333  353.10476685  370.21716309  387.18969727  403.92922974
#   420.34033203  436.32601929  451.78872681  466.63137817  480.75827026
#   494.07611084  506.49505615  517.92974854  528.3001709   537.53265381
#   545.56091309  552.32653809  557.77990723  561.88061523  564.5982666
#   565.91247559  565.81341553  564.30187988  561.38916016  557.09698486
#   551.45727539  544.51159668  536.31103516  526.91503906  516.39099121
#   504.81359863  492.2635498   478.8269043   464.59411621  449.65884399
#   434.11700439]
